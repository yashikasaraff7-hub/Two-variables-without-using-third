# %% [markdown]
# <a href="https://colab.research.google.com/github/yashikasaraff7-hub/Two-variables-without-using-third/blob/main/Two_var_without_using_third_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Input values
a = 10
b = 20

print("Before swapping:")
print("a =", a)
print("b =", b)

# Swapping without third variable
a, b = b, a

print("\nAfter swapping:")
print("a =", a)
print("b =", b)
# Out:
# Before swapping:
# a = 10
# b = 20
#
# After swapping:
# a = 20
# b = 10
